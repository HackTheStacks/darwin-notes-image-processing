# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

X = np.arange(0,10,0.1)
Y = np.sin(X)
test_data = pd.DataFrame(np.array([X,Y]).T, columns=['x','y'])
test_data.plot(kind="scatter", x='x', y='y')

# %%
from downsample import downsample
downsample(test_data).plot(kind="scatter", x='x', y='y')
